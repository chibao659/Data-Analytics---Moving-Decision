# %%
import pandas as pd
url= r'C:\Users\chi_b\OneDrive\Desktop\Analytics QMST 5336\Project\home_price_zip.csv'
full_csv_df = pd.read_csv(url,parse_dates = True)
full_csv_df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County         NaN  ...
# 1          Chicago-Naperville-Elgin      Cook County    296113.0  ...
# 2       New York-Newark-Jersey City  New York County         NaN  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County    203140.0  ...
# 4          Chicago-Naperville-Elgin      Cook County    462086.0  ...
#
#    2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# ...

# %%
full_csv_df = full_csv_df.dropna()

# %%
atlanta_metro_df = full_csv_df[full_csv_df['Metro'].str.contains('Atlanta')]
atlanta_metro_df.head()
# Out:
#     RegionID  SizeRank  RegionName RegionType StateName State           City  \
# 36     71067        37       30349        Zip        GA    GA      Riverdale
# 51     70829        52       30044        Zip        GA    GA  Lawrenceville
# 57     70828        58       30043        Zip        GA    GA  Lawrenceville
# 64     70874        65       30096        Zip        GA    GA         Duluth
# 68     70810        69       30024        Zip        GA    GA        Suwanee
#
#                             Metro       CountyName  1996-01-31  ...  \
# 36  Atlanta-Sandy Springs-Roswell   Clayton County     97498.0  ...
# 51  Atlanta-Sandy Springs-Roswell  Gwinnett County    116326.0  ...
# 57  Atlanta-Sandy Springs-Roswell  Gwinnett County    142360.0  ...
# 64  Atlanta-Sandy Springs-Roswell  Gwinnett County    130095.0  ...
# 68  Atlanta-Sandy Springs-Roswell  Gwinnett County    189623.0  ...
#
#     2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# ...

# %%
atlanta_metro_df.describe()
# Out:
#            RegionID      SizeRank    RegionName     1996-01-31     1996-02-29  \
# count    173.000000    173.000000    173.000000     173.000000     173.000000
# mean   70960.242775   5344.687861  30226.393064  126006.080925  126272.462428
# std      146.974958   5462.882107    250.087325   62128.315304   62325.016330
# min    70789.000000     37.000000  30002.000000   30676.000000   30581.000000
# 25%    70855.000000   1336.000000  30076.000000   87445.000000   87618.000000
# 50%    70946.000000   3055.000000  30179.000000  114755.000000  115132.000000
# 75%    71026.000000   7839.000000  30306.000000  145740.000000  145903.000000
# max    71708.000000  25206.000000  31830.000000  521445.000000  523727.000000
#
#           1996-03-31     1996-04-30     1996-05-31     1996-06-30  \
# count     173.000000     173.000000     173.000000     173.000000
# mean   126491.202312  126988.427746  127465.127168  127998.294798
# std     62456.551212   62781.092392   63038.398368   63318.165204
# ...

# %%
atlanta_metro_df = atlanta_metro_df.drop(['RegionID','SizeRank','RegionType','State','StateName','CountyName','City','Metro'],axis=1)

# %%
atlanta_metro_df = atlanta_metro_df.rename(columns={'RegionName':'ZipCode'})

# %%
atlanta_metro_df
# Out:
#        ZipCode  1996-01-31  1996-02-29  1996-03-31  1996-04-30  1996-05-31  \
# 36       30349     97498.0     98023.0     98438.0     99297.0    100063.0
# 51       30044    116326.0    116520.0    116730.0    117126.0    117532.0
# 57       30043    142360.0    142525.0    142714.0    143104.0    143498.0
# 64       30096    130095.0    130324.0    130569.0    131071.0    131594.0
# 68       30024    189623.0    190028.0    190159.0    190667.0    191010.0
# ...        ...         ...         ...         ...         ...         ...
# 18453    30218     57624.0     58032.0     58023.0     58379.0     58468.0
# 18799    30641     95779.0     95842.0     96130.0     95992.0     96220.0
# 19085    30137    100980.0    101096.0    101272.0    101662.0    102079.0
# 22713    31085     51988.0     51932.0     51701.0     51369.0     51125.0
# 23772    30177     55817.0     55935.0     55838.0     56028.0     56266.0
#
# ...

# %%
atlanta_metro_df.to_csv(r'C:\Users\chi_b\OneDrive\Desktop\Analytics QMST 5336\Project\atlanta_metro_zip.csv')

# %%
atlanta_metro_df = atlanta_metro_df.set_index('ZipCode')

# %%
atlanta_metro_df = atlanta_metro_df.transpose()
atlanta_metro_df
# Out:
# ZipCode        30349     30044     30043     30096     30024     30281  \
# 1996-01-31   97498.0  116326.0  142360.0  130095.0  189623.0  112115.0
# 1996-02-29   98023.0  116520.0  142525.0  130324.0  190028.0  112332.0
# 1996-03-31   98438.0  116730.0  142714.0  130569.0  190159.0  112464.0
# 1996-04-30   99297.0  117126.0  143104.0  131071.0  190667.0  112763.0
# 1996-05-31  100063.0  117532.0  143498.0  131594.0  191010.0  112992.0
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-30  171519.0  224911.0  258600.0  258759.0  379532.0  191100.0
# 2020-07-31  172848.0  226691.0  260530.0  260358.0  381592.0  192900.0
# 2020-08-31  174538.0  228803.0  262827.0  262220.0  383821.0  194407.0
# 2020-09-30  176047.0  231371.0  265628.0  264567.0  386815.0  196252.0
# 2020-10-31  177895.0  234334.0  268900.0  267491.0  390255.0  198270.0
#
# ZipCode        30040     30318     30188     30052  ...    30293     30182  \
# ...

# %%
atlanta_metro_df.index = pd.to_datetime(atlanta_metro_df.index)

# %%
atlanta_metro_df.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
atlanta_metro_df.to_csv(r'C:\Users\chi_b\OneDrive\Desktop\Analytics QMST 5336\Project\atlanta_metro_zip_date_index.csv')
